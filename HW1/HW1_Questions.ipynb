# %% [markdown]
# <a href="https://colab.research.google.com/github/bookwork123/MachineLearning/blob/main/HW1/HW1_Questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1.** **Based on the instructional videos, what are the key steps for managing files between Google Colab and GitHub?**
#
# ---
# The key steps for managing files between Google Colab and GitHub are to:
#
# a) create and prepare the GitHub repository you want to use for your Colab notebooks
#
# b) create or open your notebook in Google Colab and perform the necessary actions and changes
#
# c) in your notebook, use the option "Save a copy in GitHub" and point the file to your repository and the correct folder
#
# d) visit your repository to ensure it is correct

# %% [markdown]
# **2.** **Did all Module 0 notebooks execute successfully in Colab on the first try, or did you need to adjust any syntax or dependencies?**
#
#
#
# ---
# All of the Module 0 notebooks executed successfully in Colab on the first try.

# %% [markdown]
# **3. Explain how you created your repository and organized your files (whether using VS Code or the GitHub web interface).**
# ---
#
# I logged into GitHub and created my new repository, then added you (Dr. Forouraghi) as a collaborator. I cloned the repository to a folder on my computer so that I could open it in VSCode, where I added a HW1 folder, as well as a file called **example.py**. I added the file so that the otherwise empty folder would show properly on GitHub. When I was interacting with the notebooks, I would just save them under that folder in my repository using Colab's ability to save to GitHub.

# %% [markdown]
# **4. Why is establishing a strong command of basic Python data structures and syntax critical before moving on to core machine learning algorithms?**
#
# ---
#
# Establishing a strong command of basic Python data structures and syntax is critical before moving on to core machine learning algorithms because it enables you to properly understand the code you are reading, writing, or generating. Without this knowledge, you don't actually have a grasp on what is happening "under the hood" of your program, making it difficult to have an understanding of what the machine learning algorithms are doing.
