# %% [markdown]
# <a href="https://colab.research.google.com/github/bookwork123/MachineLearning/blob/main/HW2/analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. What challenges did you encounter when loading and inspecting a raw external dataset from Kaggle compared to pre-packaged datasets?
#
# The website wasn't very intuitive when it came to downloading the data with the options it presented, since I didn't want to configure anything extra to download it.
# I chose to download the .zip file and extract the data which was easy enough.
# Compared to pre-packaged data, I had to clean and impute data due to some null columns, which wasn't hard but is time-consuming and annoying.

# %% [markdown]
# 2. How did you determine which columns required missing value imputation versus other data cleaning methods, and what strategy did you choose?
#
# I determined that the encryption_used column required missing value imputation by using df.info(), which indicated there were less observations in that column compared to all of the others, which were equal. To do the imputation, I used the fillna() method and filled every empty value with the column's mode.

# %% [markdown]
# 3. Explain how the Scikit-Learn ColumnTransformer and Pipeline streamline the data preparation process and prevent data leakage across preprocessing steps.
#
# The Scikit-Learn ColumnTransformer and Pipeline streamline the data prepration process by simplifying what would otherwise be a strenous and time-consuming mathametical undertaking into a few lines of code. Instead of having to manually scale values and convert categorical data to numeric values to scale them as well, we can use Scikit-Learn to make the transformation happen very quickly. These tools also help prevent data leakage by consolidating the transformation/pipeline actions to the training data and applying them consistently to the test data.

# %% [markdown]
# 4. Based on your correlation matrix and heatmap, which features show the strongest relationships with the target variable (attack_detected), and what operational insights do these relationships reveal?
#
# The features with the strongest relationships to the target variable (attack_detected) are failed_logins (0.36), login_attempts (0.28), and ip_reputation_score (0.21). These relationships reveal that multiple failed logins is the strongest indicator of a cyberattack, while login attempts and IP reputation are decent indicators of a cyberattack. Cyberattackers are running multiple login attempts and as a result, failing many of them. The IP reputation score is not something to be overlooked.
